# %%
import numpy as np
import json
from pathlib import Path
import matplotlib.pyplot as plt

src_dir = Path("/home/iailab36/iser/models/sts_vec=10000/corex_n_hidden=64_iter=30")
assert src_dir.exists()

# %%
with open(src_dir / "info.json", "r") as f:
    info = json.load(f)

# %%
tc_history = np.array(info["tc_history"])
plt.figure(figsize=(15, 8))
plt.plot([str(i) for i in range(len(tc_history))], tc_history)
plt.show()
